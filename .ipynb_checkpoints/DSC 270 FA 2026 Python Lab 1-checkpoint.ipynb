# %% [markdown]
# # Python Lab 1: Discovering the Jupyter Notebook
# **Shreyup Bhandari**
# *DSC270*
# *8/26/2026*

# %%
# Change this Markdown cell to a code cell
# Then run this cell!
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ## This is a demo of creating a markdown cell in Jupyter Notebook.
# ### What about creating a H3?

# %% [markdown]
# - Bulleted list example.
# - Anohter bulleted list example.
# 1. A number list now.
# 2. This is another numbered list member.
# *Sould we italisize this?*
# **Or bold this?**
#
# [I wonder what this link leads to:](https://www.centre.edu/about/faculty-staff/thomas-e-allen)

# %% [markdown]
# ## Task 3: Variable Creation and Assignment
#
# Create the following variables in a new code cell below this instruction:
#
# - `student_name`: Assign your name as a string.
# - `favorite_number`: Assign your favorite number as an integer.
# - `average_score`: Assign a float value representing an average score.
# - `is_enrolled`: Assign a boolean value (True or False) indicating if you are enrolled.
# - `courses`: Create a list containing the names of the courses you are taking.
#
# Do not delete this instruction cell. Add a new code cell below to complete these tasks.

# %%
student_name=str("Shreyup Bhandari")
favorite_number=int(37)
average_score=float(23.4)
is_enrolled=True
courses=['MAT235','MAT240','CSC270','DSC270','MAT405','MAT199']
print(student_name)
print(type(student_name))
print(favorite_number)
print(type(favorite_number))
print(average_score)
print(type(average_score))
print(is_enrolled)
print(type(is_enrolled))
print(courses)
print(type(courses))
# Out:
# Shreyup Bhandari
# <class 'str'>
# 37
# <class 'int'>
# 23.4
# <class 'float'>
# True
# <class 'bool'>
# ['MAT235', 'MAT240', 'CSC270', 'DSC270', 'MAT405', 'MAT199']
# <class 'list'>

# %% [markdown]
# ### Example, not your solution
#
# The two cells below show the pattern for a single variable. Your answer to Task 4 needs all five, in your own new cell.

# %%
student_name = "Bob"

# %%
print(student_name)
print(type(student_name))
# Out:
# Bob
# <class 'str'>

# %% [markdown]
# ## Task 5: Debugging Practice
#
# Below is a code cell with an error. Run it, identify the error, and document your findings in a Markdown cell.

# %%
# Code with a bug
total_sales = 0
total_sales = total_sales + 100
print("Total sales after update:", total_sales)
# Out:
# Total sales after update: 100

# %% [markdown]
# After explaining the error, correct the code in the same cell so that it runs without issues.

# %% [markdown]
# # Error in the code above:
# ## Variable accessed without initialization.
# The variable total_sales was iterated without being initalized before.

# %% [markdown]
# ## Task 6: Understanding Type Casting
#
# In a new Markdown cell below this instruction, explain the difference between explicit and implicit type casting. Use clear and concise language.
#
# After your explanation, add two new code cells:
#
# 1. In the first code cell, provide at least 3 examples of implicit type casting.
# 2. In the second code cell, provide at least 3 examples of explicit type casting.
#
# **Note:** From this point on, unless otherwise noted, do not delete the instruction cells. Add your solutions (in Markdown or code, as needed) below.

# %% [markdown]
# ## Difference between implicit and explicit type casting.
# Implicit type casting is python's way of automatically doing type conversions while explicit type casting requires you to *explicitly* do type conversions.

# %%
2.2+3
6.00+4
2+3.567
# Out:
# 5.567

# %%
str(2)
int("34")
float("34.4")
# Out:
# 34.4

# %% [markdown]
# ## Final Check: Restart and Run All
#
# 1. Before you finish this lab, restart the kernel and run all cells to make sure everything still works. (Hint: there is a single command that does this.)
# 2. Check for any errors, and make sure every output is what you expect.
# 3. Show your completed notebook to your instructor.
# 4. Upload the notebook to Moodle, and keep a copy in your own OneDrive.
#
# ### General Instructions for Labs
#
# - If you do not finish during the lab hour, complete it as homework. **Labs are due at the start of the next class session.**
# - A late lab earns reduced credit, capped at 60. Late work is accepted until the start of class on the day of the test covering this module, and not after.
# - A file that is empty, corrupted, or will not open is not a submission. Replace it within 24 hours and it earns credit as late work.
# - Moodle carries the official deadline. If a deadline ever changes, the change appears on Moodle first.
