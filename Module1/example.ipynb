# %%
import numpy as np

# %%
scores = np.array([
    [88, 92, 85, 91, 84],   # Alice
    [78, 81, 79, 76, 74],   # Bob
    [94, 93, 90, 95, 91],   # Carol
    [70, 78, 65, 69, 67],   # David
])

# %%
students = ["Alice", "Bob", "Carol", "David"]
tests = ["Test1", "Test2", "Test3", "Test4", "Test5"]

# %%
scores.shape
# Out:
# (4, 5)

# %%
result=scores.sum(axis=1).sum()
print(result)
# Out:
# 1640

# %%
highestScoreOnEachTest=np.argmax(scores,axis=1)

# %%
for items in highestScoreOnEachTest:
    print(tests[items])
# Out:
# Test2
# Test2
# Test4
# Test2

# %%
product=scores.prod()
print(product)
# Out:
# -5320042544922329088

# %%
productNew=scores.astype(float).prod()
print(productNew)
# Out:
# 1.6478221276603993e+38

# %%
scores.min(axis=0)
# Out:
# array([70, 78, 65, 69, 67])

# %%
students[scores[:,0].argmax()]
# Out:
# 'Carol'

# %%
t=np.array([60,91,78,91])
t.max()
t.argmax()
np.where(t==t.max())
# Out:
# (array([1, 3]),)

# %%
(scores.sum(axis=1)/scores.shape[1]).round(0)
# Out:
# array([88., 78., 93., 70.])

# %%
scores.mean(axis=1)
# Out:
# array([88. , 77.6, 92.6, 69.8])

# %%
scores.std(axis=0).round(1)
# Out:
# array([ 9.2,  6.6,  9.4, 10.6,  9.2])

# %%
sorted(students,key= lambda student:student[1])
# Out:
# ['Carol', 'David', 'Alice', 'Bob']

# %%
np.sort(scores)
# Out:
# array([[84, 85, 88, 91, 92],
#        [74, 76, 78, 79, 81],
#        [90, 91, 93, 94, 95],
#        [65, 67, 69, 70, 78]])

# %%
scores
# Out:
# array([[88, 92, 85, 91, 84],
#        [78, 81, 79, 76, 74],
#        [94, 93, 90, 95, 91],
#        [70, 78, 65, 69, 67]])

# %%
alice=scores[0]

# %%
alice>90
# Out:
# array([False,  True, False,  True, False])

# %%
alice[alice>90]
# Out:
# array([92, 91])

# %%
scores[scores.mean(axis=1) > 80]
# Out:
# array([[88, 92, 85, 91, 84],
#        [94, 93, 90, 95, 91]])
